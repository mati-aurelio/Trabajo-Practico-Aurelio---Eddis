# %% [markdown]
# <a href="https://colab.research.google.com/github/mati-aurelio/Trabajo-Practico-Aurelio---Eddis/blob/main/ProyectoDSParteI%2BAurelio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRIMER ENTREGA - "EDDIS"

# %% [markdown]
# El presente trabajo se enmarca en el objetivo de aplicar técnicas de Data Science y Machine Learning para la predicción del comportamiento de los inscriptos de la empresa "Eddis" para las sedes de Ezeiza, Cañuelas y Monte Grande. Específicamente, se busca desarrollar un modelo predictivo capaz de determinar la Categoría del Plan de Estudio que una persona seleccionará, basándose en variables demográficas y de estatus personal

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('/content/Data.xlsx', sheet_name='alumnos_inscriptos (66)')

df.head(15)
# Out:
#         Fecha        Centro                           Alumno   Legajo  \
# 0  2023-01-02        Ezeiza            GONZALEZ YESICA PAOLA  1631686
# 1  2023-01-03        Ezeiza         GONZALEZ LEONARDO DANIEL  1631687
# 2  2023-01-04  Monte Grande  GIGENA ZITNIK ALEJANDRO NICOLAS  1641678
# 3  2023-01-04        Ezeiza          CABALLERO CARLOS DANIEL  1631689
# 4  2023-01-04  Monte Grande        DRUSETICH CARLOS NAZARENO  1641679
# 5  2023-01-10      Cañuelas             MENDEZ CAMILA MAGALI  2850108
# 6  2023-01-10      Cañuelas             MENDEZ CAMILA MAGALI  2850108
# 7  2023-01-10  Monte Grande            MUñOZ STEPHANIE ROCIO  1641689
# 8  2023-01-16  Monte Grande             BARRIOS GASTON ELIAS  1641699
# 9  2023-01-17  Monte Grande                     GARCIA KEVIN  1641705
# 10 2023-01-17  Monte Grande                     GODOY SILVIA  1641706
# 11 2023-01-19  Monte Grande            SOTO FERNANDO GABRIEL  1641712
# 12 2023-01-25  Monte Grande           ALVAREZ DANIEL ALBERTO  1641723
# 13 2023-01-26  Monte Grande                  CáCERES NICOLAS  1641725
# 14 2023-01-27  Monte Grande           BENíTEZ LUCAS EZEQUIEL  1641727
#
#    Documento               Telefono        Curso  \
# 0   32091363             1165927506     HIGIENE2
# 1   33588975             1134394845       AACC11
# 2   33401481             1540551362       AACC11
# 3   27904590             1131152116       AACC11
# 4   31315864             1121559411       AACC11
# 5   44424438   +54 9 2226 45-8655 0  TECEXTRACC5
# 6   44424438   +54 9 2226 45-8655 0      LABORA4
# 7   42885024             1161320746       COSME6
# 8   42961776  1134227932 1134227921       AACC11
# 9   42459017             1171457303       AACC11
# 10  28697815             1153464446   MASAJISTA8
# 11  43885944             1128930380     COMPOFI8
# 12  29699284             1132944800       AACC11
# 13  34272350             1156964543       CELU29
# 14  42661628             1156138157     EXTRAC24
#
#                                      Plan de Estudio  \
# 0      AUXILIAR EN SEGURIDAD E HIGIENE EN EL TRABAJO
# 1   INSTALACIÓN Y REPARACIÓN DE AIRES ACONDICIONADOS
# 2   INSTALACIÓN Y REPARACIÓN DE AIRES ACONDICIONADOS
# 3   INSTALACIÓN Y REPARACIÓN DE AIRES ACONDICIONADOS
# 4   INSTALACIÓN Y REPARACIÓN DE AIRES ACONDICIONADOS
# 5                          TÉCNICO EN EXTRACCIONISTA
# 6      ASISTENTE DE LABORATORIO DE ANÁLISIS CLÍNICOS
# 7                                       COSMETOLOGIA
# 8   INSTALACIÓN Y REPARACIÓN DE AIRES ACONDICIONADOS
# 9   INSTALACIÓN Y REPARACIÓN DE AIRES ACONDICIONADOS
# 10                             MASAJISTA PROFESIONAL
# 11                         COMPUTACION PARA OFICINAS
# 12  INSTALACIÓN Y REPARACIÓN DE AIRES ACONDICIONADOS
# 13            PROGRAMACION Y REPARACION DE CELULARES
# 14                                    EXTRACCIONISTA
#
#                                   Categoria        Ciudad     Genero  \
# 0                       Otros/Sin Categoría        Ezeiza   Femenino
# 1                  Oficios Técnicos y Hogar        Ezeiza  Masculino
# 2                  Oficios Técnicos y Hogar  Monte Grande  Masculino
# 3                  Oficios Técnicos y Hogar        Ezeiza  Masculino
# 4                  Oficios Técnicos y Hogar  Monte Grande  Masculino
# 5                  Laboratorio y Extracción      CAÑUELAS   Femenino
# 6                 Salud y Asistencia Médica      CAÑUELAS   Femenino
# 7             Estética y Bienestar Personal  Monte Grande   Femenino
# 8                  Oficios Técnicos y Hogar  Monte Grande  Masculino
# 9                  Oficios Técnicos y Hogar  Monte Grande  Masculino
# 10            Estética y Bienestar Personal  Monte Grande   Femenino
# 11                      Otros/Sin Categoría  Monte Grande  Masculino
# 12                 Oficios Técnicos y Hogar  Monte Grande  Masculino
# 13  Tecnología y Reparación de Dispositivos  Monte Grande  Masculino
# 14                 Laboratorio y Extracción  Monte Grande  Masculino
#
#    Secundario Trabajo         Asesor  Edad  Seña Fecha Inicio  Dia  Mes  Anio
# 0          SI      SI         YAMILA  39.0     0   2023-03-13   13    3  2023
# 1          SI      SI  EDDIS CENTRAL  36.0     0   2023-01-09    9    1  2023
# 2          SI      SI       AGOSTINA  37.0     0   2023-01-09    9    1  2023
# 3          SI      SI  EDDIS CENTRAL  45.0     0   2023-01-09    9    1  2023
# 4          NO      SI       AGOSTINA  40.0     1   2023-01-09    9    1  2023
# 5          SI      SI         YAMILA  23.0     0   2023-03-13   13    3  2023
# 6          SI      SI         YAMILA  23.0     0   2023-03-13   13    3  2023
# 7          SI      NO  EDDIS CENTRAL  28.0     0   2023-01-09    9    1  2023
# 8          SI      SI       AGOSTINA  24.0     0   2023-01-09    9    1  2023
# 9          SI      SI       AGOSTINA  26.0     0   2023-01-09    9    1  2023
# 10         SI      SI         YAMILA  44.0     0   2023-01-09    9    1  2023
# 11         SI      SI         YAMILA  23.0     0   2023-03-13   13    3  2023
# 12         SI      SI       AGOSTINA  43.0     0   2023-01-09    9    1  2023
# 13         SI      SI         YAMILA  37.0     0   2023-01-09    9    1  2023
# 14         NO      SI       GABRIELA  25.0     0   2023-01-09    9    1  2023

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Fecha: Fecha en la que se registró la inscripción del alumno en la plataforma.
#
# Centro: Centro o sucursal de la plataforma donde se efectúa la inscripción.
#
# Alumno: Nombre completo del alumno inscrito.
#
# Legajo: Número de legajo o código único asignado al alumno en el sistema.
#
# Documento: Número de documento de identidad del alumno.
#
# Telefono: Número de teléfono de contacto del alumno.
#
# Curso: Código o identificador interno del curso.
#
# Plan de Estudio: Nombre completo y oficial del curso o plan de estudio en el que se inscribe el alumno.
#
# Ciudad: Ciudad o localidad de residencia del alumno o desde donde se inscribe.
#
# Genero: Género del alumno.
#
# Secundario: Indica si el alumno ha completado la educación secundaria.
#
# Trabajo: Indica si el alumno se encuentra trabajando al momento de la inscripción.
#
# Asesor: Nombre del asesor o consejero de ventas que tramitó la inscripción.
#
# Edad: Edad del alumno al momento de la inscripción.
#
# Seña: Indica la presencia o estado del pago de una seña inicial al inscribirse.
#
# Fecha Inicio: Fecha programada para el inicio de la cursada.
#
# Dia: Componente del día de la fecha de inscripción.
#
# Mes: Componente del mes de la fecha de inscripción.
#
# Anio: Componente del año de la fecha de inscripción.

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('/content/Data.xlsx')
len(df)
# Out:
# 3833

# %%
df = pd.read_excel('/content/Data.xlsx')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3833 entries, 0 to 3832
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Fecha            3833 non-null   datetime64[ns]
#  1   Centro           3833 non-null   object
#  2   Alumno           3833 non-null   object
#  3   Legajo           3833 non-null   int64
#  4   Documento        3833 non-null   object
#  5   Telefono         3833 non-null   object
#  6   Curso            3833 non-null   object
#  7   Plan de Estudio  3833 non-null   object
#  8   Categoria        3833 non-null   object
#  9   Ciudad           3684 non-null   object
#  10  Genero           3833 non-null   object
#  11  Secundario       3833 non-null   object
#  12  Trabajo          3833 non-null   object
#  13  Asesor           3833 non-null   object
#  14  Edad             3832 non-null   float64
#  15  Seña             3833 non-null   int64
#  16  Fecha Inicio     3833 non-null   datetime64[ns]
#  17  Dia              3833 non-null   int64
#  18  Mes              3833 non-null   int64
#  19  Anio             3833 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(5), object(12)
# memory usage: 599.0+ KB

# %%
df.describe().round(1)
# Out:
#                                Fecha     Legajo    Edad    Seña  \
# count                           3833     3833.0  3832.0  3833.0
# mean   2024-10-12 10:22:30.587007488  1841012.7    32.1     0.1
# min              2023-01-02 00:00:00  1630065.0     0.0     0.0
# 25%              2024-03-25 00:00:00  1633318.0    23.0     0.0
# 50%              2024-11-15 00:00:00  1642710.0    30.0     0.0
# 75%              2025-05-19 00:00:00  1643858.0    40.0     0.0
# max              2025-11-22 00:00:00  2850720.0    76.0     1.0
# std                              NaN   451150.3    11.0     0.3
#
#                         Fecha Inicio     Dia     Mes    Anio
# count                           3833  3833.0  3833.0  3833.0
# mean   2024-09-20 22:09:55.460474624    13.3     6.2  2024.3
# min              2022-04-11 00:00:00     1.0     1.0  2022.0
# 25%              2024-03-18 00:00:00    11.0     3.0  2024.0
# 50%              2024-10-14 00:00:00    13.0     6.0  2024.0
# 75%              2025-04-29 00:00:00    17.0     8.0  2025.0
# max              2025-12-19 00:00:00    31.0    12.0  2025.0
# std                              NaN     4.2     3.1     0.7

# %%
df.Fecha.unique()
# Out:
# <DatetimeArray>
# ['2023-01-02 00:00:00', '2023-01-03 00:00:00', '2023-01-04 00:00:00',
#  '2023-01-10 00:00:00', '2023-01-16 00:00:00', '2023-01-17 00:00:00',
#  '2023-01-19 00:00:00', '2023-01-25 00:00:00', '2023-01-26 00:00:00',
#  '2023-01-27 00:00:00',
#  ...
#  '2025-11-12 00:00:00', '2025-11-13 00:00:00', '2025-11-14 00:00:00',
#  '2025-11-15 00:00:00', '2025-11-17 00:00:00', '2025-11-18 00:00:00',
#  '2025-11-19 00:00:00', '2025-11-20 00:00:00', '2025-11-21 00:00:00',
#  '2025-11-22 00:00:00']
# Length: 811, dtype: datetime64[ns]

# %%
df.Centro.unique()
# Out:
# array(['Ezeiza', 'Monte Grande', 'Cañuelas'], dtype=object)

# %%
df.Curso.unique()
# Out:
# array(['HIGIENE2', 'AACC11', 'TECEXTRACC5', 'LABORA4', 'COSME6',
#        'MASAJISTA8', 'COMPOFI8', 'CELU29', 'EXTRAC24', 'ADMREDES3',
#        'FARMA4', 'ELEC12', 'HIGIENE3', 'AACC12', 'INTROVINO3', 'EXTRAC25',
#        'SECRE3', 'TREFRI12', 'MASAJISTA9', 'COSME5', 'CELU30',
#        'EDICFOTOS6', 'RRHH15', 'TECEXTRACC7', 'FARMA17', 'TECEXTRACCB5',
#        'ADUANA6', 'SECREMED10', 'TECEXTRACCB6', 'ADMHOTELERA3', 'MANOS4',
#        'EDICFOTOS1', 'gastroeddis4', 'gastroeddis5', 'COMPOFI5',
#        'TRAINER12', 'SEÑA8', 'ELEC13', 'SUEIMP17', 'TREFRI13',
#        'TECEXTRACC8', 'FARMA15', 'EXCELAV5', 'ADMIN7', 'PREPAFI5',
#        'pasteeddis7', 'ENFDOM27', 'TREFRI6', 'TURIS3', 'CELU31', 'SECRE9',
#        'RRHH16', 'FARMA16', 'CARDIO28', 'MECAUTO5', 'ADMHOTELERA4',
#        'decotortas18', 'TERAP13', 'CELU32', 'ENFDOM29', 'ADMSALUD12',
#        'COSME7', 'MASAJISTA10', 'EDICFOTOS7', 'CELU33', 'SEÑA9',
#        'TECEXTRACC9', 'CARDIO29', 'EXTRAC26', 'AACC13', 'ENFDOM28',
#        'LOGIS6', 'EXCELAV6', 'SECRE10', 'TERAP14', 'CARDIO31', 'tpizza5',
#        'NUTRIDEPOR15', 'MASAJISTA11', 'ADMREDES5', 'RRHH17', 'SEÑA10',
#        'MDEPORTIVO5', 'ADUANA7', 'TREFRI14', 'SECREMED11', 'CARDIO30',
#        'SECREMED6', 'CELU34', 'TRAINER13', 'SUEIMP18', 'SECRE11',
#        'COSME8', 'MASAJISTA12', 'EDICFOTOS8', 'TREFRI15', 'NUTRIDEPOR16',
#        'AUXCONTA1', 'TECEXTRACC10', 'ELEC14', 'AACC14', 'SUEIMP7',
#        'ENFDOM30', 'EXTRAC27', 'ADMSALUD13', 'CELU35', 'AACC15',
#        'EVENTOS5', 'ENFDOM31', 'CARDIO33', 'TREFRI16', 'PROMORCP.EO1',
#        'MASO4M1', 'PLASMA.EO1', 'EXTRAC28', 'MASOT6', 'MANOS6',
#        'SUEIMP19', 'COMPOFI9', 'ADMSALUD15', 'INTROPROGRAMACION3',
#        'CELU.EO1', 'CELUII1', 'CARDIO34', 'MASAJISTA13', 'TRAINER14',
#        'FARMA19', 'LOGIS7', 'CELU36', 'BARTENDER17', 'AUXCONTA2',
#        'pasteeddis8', 'VIANDAS.EO1', 'SUEIMP20', 'MASAJISTA14',
#        'ENFDOM12', 'ADMIN10', 'Alfajores1', 'SECREMED12', 'TECEXTRACC11',
#        'TERAP19', 'FARMA18', 'TURIS4', 'TERAP15', 'RCP.EO1', 'tpizza6',
#        'EXTRAC29', 'TECMUSC.EO1', 'ADMINHOTEL.EO1', 'ENTFUNCIONAL.EO1',
#        'COSME9', 'ENFDOM32', 'ASEIMAGEN2', 'RRHH18', 'ADMREDES7',
#        'SEÑA11', 'CELU37', 'EXCELAV7', 'LABORA6', 'TERAP20', 'SUEIMP21',
#        'TECEXTRACC12', 'RCP12', 'EXTRAC11', 'VIAN12', 'ELEC15',
#        'PASTASGOUR4', 'VIAN11', 'SEÑA12', 'CELU38', 'SOBREPESO.EO1',
#        'TREFRI17', 'SUEIMP8', 'MASAJISTA15', 'DIGRAF7', 'MDEPORTIVO6',
#        'sushi10', 'CARDIO36', 'TECEXTRACCB7', 'ENFDOM33', 'pasteempre7',
#        'MASOT8', 'ADMSALUD17', 'AACC16', 'BARTENDER7', 'MASOT9',
#        'BARTENDER18', 'EXCELAV8', 'ELEC16', 'COMPOFI10', 'EXTRAC30',
#        'SECREMED14', 'TERAP21', 'MASAJISTA16', 'MASAJISTA17', 'TREFRI18',
#        'HUERTA.EO1', 'COSME10', 'TECEXTRACC13', 'SUEIMP22', 'RRHH20',
#        'SEÑA13', 'BARTENDER19', 'ENTADULTO.EO1', 'CELU39', 'FARMA22',
#        'LABORA18', 'ENFDOM34', 'pasteempre8', 'decotortas23',
#        'dulcesnavideños4', 'FARMA20', 'CELU40', 'CEJASYPEST.EO1',
#        'COLORIMETRÍA.EO1', 'TECENUÑAS.EO1', 'MASOT7', 'ENTFUNCION16',
#        'NUTRIDEPOR17', 'TRAINER16', 'NEUROINF.EO1', 'AACC7', 'VIAN13',
#        'EXTRAC31', 'ADMSALUD16', 'EXCELAV9', 'AACC18', 'MASAJISTA19',
#        'FARMA23', 'ENTFUNCION19', 'tpizza7', 'AACC17', 'ADMREDES9',
#        'ADMREDES8', 'MASAJISTA18', 'CELU41', 'ADMSALUD18', 'SECREMED15',
#        'TECEXTRACC15', 'ENFDOM35', 'pasteempre9', 'ELEC17', 'TREFRI19',
#        'SEÑA14', 'BARTENDER20', 'AACC19', 'LABORA19',
#        'presencial.extrac1', 'ASESORAMIENTOIM.EO1', 'TECEXTRACC14',
#        'FARMA21', 'CARDIO38', 'COSME11', 'TERAP22', 'EXTRAC33',
#        'SUEIMP23', 'COMPOFI11', 'AUXCONTA3', 'gastroeddis7', 'EVENTOS6',
#        'MDEPORTIVO7', 'RRHH22', 'RRHH21', 'CELUII4', 'TRAINER17',
#        'TREFRI20', 'EVENTOS4', 'TERAP18', 'MASAJISTA20', 'ADMHOTELERA6',
#        'CARDIO37', 'CELU43', 'ENFDOM37', 'CELU42', 'ASEIMAGEN4',
#        'CARDIO40', 'CELUII5', 'HIGIENE4', 'decotortas26', 'EXTRAC32',
#        'COSME12', 'NUTRIDEPOR18', 'ENTFUNCION20', 'CARDIO39', 'LOGIS8',
#        'ETEM7', 'SEÑA15', 'CELU46', 'SUEIMP24', 'ENFDOM36', 'ENFDOM39',
#        'excel.eo1', 'decotortas25', 'MASOT10', 'ETEM8', 'MANOS8',
#        'ENFDOM38', 'ADUANA8', 'RRHH23', 'CELU44', 'pasteeddis10',
#        'liderazgo.eo1', 'ELEC18', 'PASTAS.EO1', 'pasteempre10',
#        'ENFDOM40', 'SUSHI.EO1', 'MASAJISTA21', 'CARDIO41', 'ADMSALUD19',
#        'TECCELU1', 'TREFRI21', 'ENTFUNCION18', 'ADMIN11', 'MASOT11',
#        'PLAYSTATION.EO1', 'PELUMASC.EO1', 'ELEC19', 'presencial.cardio1',
#        'TRAINER18', 'AACC20', 'TECEXTRACC16', 'LABORA20', 'SECRE14',
#        'EXTRAC34', 'AACC21', 'SECRE13', 'COSME13', 'SEÑA16', 'RCP16',
#        'TERAP23', 'CELU45', 'CEXPERIENCE.EO1', 'presencial.masajprof1',
#        'EXTRAC35', 'decotortas27', 'EXTENSIONISTA.EO1', 'CHATGPT.EO1',
#        'SUEIMP25', 'EMPANADAS.EO3', 'contabilidad.eo1', 'NUTRIDEPOR.EO1',
#        'NUTRIDEPOR19', 'ADMIN12', 'PIZZAS.EO1', 'TECEXTRACCB9', 'MASO4M2',
#        'LABORA21', 'DECODETORTAS.EO1', 'TRAINER19', 'MASASFINAS.EO1',
#        'CARDIO42', 'EXTRAC36', 'liqsueldos.eo1', 'FARMA25', 'ENFDOM42',
#        'RRHH24', 'COSME14', 'pasteempre11', 'RCP17', 'decotortas29',
#        'CELU47', 'ENFDOM41', 'excelav.eo1', 'MASAJISTA24', 'MASAJISTA22',
#        'POWERBI.EO1', 'EXTRAC37', 'PROGRAMACIÓNVJ.EO1', 'gastroeddis8',
#        'TREFRI23', 'AACC22', 'TECEXTRACC17', 'presencial.elec1',
#        'PASTEEMP.EO1', 'SUEIMP27', 'TREFRI22', 'EXCELAV11', 'ELEC21',
#        'FARMA26', 'TRAINER20', 'MASOT13', 'CELU48', 'RCP18',
#        'mandosmedios.eo1', 'ADMSALUD20', 'ADUANA9', 'REPARAPC1',
#        'ADMIN13', 'FARMA24', 'COSME15', 'MACARONS.EO1', 'AUXCONTA4',
#        'word.eo1', 'excel.eo2', 'MASAJISTA23', 'MDEPORTIVO8', 'AACC23',
#        'MASO4M4', 'pasteeddis12', 'EXTRAC38', 'MASO4M3', 'TERAP24',
#        'AACC24', 'ENFDOM43', 'TECEXTRACC18', 'MASAJISTA25', 'ENFDOM18',
#        'ADUANA4', 'TREFRI10', 'SECRE16', 'RRHH25', 'RRHH13', 'SUEIMP11',
#        'CELU26', 'HIGIENE.EO1', 'EXTRAC15', 'bartender.eo1',
#        'MDEPORTIVO3', 'AACC8', 'EXTRAC14', 'TECCELU2', 'RCP19', 'SECRE5',
#        'SUEIMP26', 'FOTOSYVIDEO.EO1', 'monotributo.eo1', 'BARTENDER22',
#        'decotortas30', 'SECREMED17', 'pasteempre12', 'presencial.aacc1',
#        'SEÑA18', 'ELEC20', 'DIGRAF3', 'EXTRAC39', 'REFLEXOLOGIA1',
#        'ambientacion.eo1', 'redessociales.eo1', 'ENFDOM44', 'EXCELAV12',
#        'RRHH14', 'COMPOFI12', 'AUXCONTA5', 'TECEXTRACC19', 'CELU21',
#        'CELU49', 'ADMSALUD21', 'ELEC9', 'CELU22', 'FARMA27', 'CARDIO44',
#        'AUTOMKP.EO1', 'LABORA22', 'CARDIO43', 'COSME16',
#        'DECODETORTAS.EO2', 'AACC25', 'TRAINER7', 'SECRE15', 'ELEC22',
#        'AACC9', 'RRHH26', 'MASAJISTA26', 'TERAP8', 'decotortas31',
#        'EXTRAC40', 'BARTENDER23', 'ENFDOM19', 'TREFRI24', 'SUEIMP12',
#        'AACC26', 'CELUII.EO1', 'ADMREDES10', 'CELU50', 'SEÑA19',
#        'MASAJISTA27', 'MACARONS.EO2', 'autocad.eo1', 'TECENUÑAS.EO2',
#        'ELEC10', 'TRAINER8', 'CEJASYPEST.EO2', 'PASTEEMP.EO2',
#        'ESTETICAINT.EO1', 'ALFAJORES.EO1', 'AACC10', 'MASOT12',
#        'TRAINER21', 'ENTFUNCION21', 'CELUII6', 'TECEXTRACCB10', 'CELU23',
#        'CELU51', 'gestionpymes.eo1', 'MASAJISTA28', 'CARDIO46',
#        'EXTRAC17', 'TECEXTRACC20', 'TREFRI25', 'EXTRAC41', 'canva.eo1',
#        'AACC27', 'ELEC23', 'PREPAFI6', 'MASOT15', 'ENFDOM45',
#        'PILATES.EO2', 'TECCELU3', 'MASO4M5', 'CARDIO45',
#        'SEMIYNAILART.EO1', 'oratoria.eo1', 'EXTRAC16', 'LABORA23',
#        'RCP14', 'PREPAFI3', 'ELEC11', 'CELU52', 'presencial.celu1',
#        'ELEC24', 'PIZZAS.EO2', 'finanzas.eo1', 'ENFDOM21',
#        'PLAYSTATION.EO2', 'RRHH27', 'EXTRAC18', 'CELU25', 'bartender.eo2',
#        'SUEIMP28', 'CELU24', 'SUEIMP14', 'SELECPERSONAL.EO2',
#        'GESTION.EO2', 'TRAINER22', 'EXTRAC19', 'AUXCONTA6', 'RCP15',
#        'EXTRAC42', 'ENFDOM46', 'ADUANA10', 'TECEXTRACCB11', 'COSME17',
#        'CEJASYPEST.EO3', 'COMPOFI13', 'MASAJISTA29', 'AACC28', 'FARMA29',
#        'EXTRAC43', 'ENTFUNCION11', 'ENFDOM23', 'TRAINER10', 'CELU53',
#        'pasteeddis6', 'SECRE7', 'tecmasajes.eo1', 'googleads.eo1',
#        'ENTFUNCION12', 'ENTFUNCION22', 'ADMREDES11', 'MANOS9', 'SECRE17',
#        'pasteempre14', 'CELU54', 'ENFDOM47', 'MECAUTO6', 'ALFAJORES.EO2',
#        'mktredes.eo1', 'SECREMED18', 'keto.eo1', 'REFLEXOLOGIA2',
#        'LABORA11', 'RCP22', 'presencial.enfdomycl1', 'presencial.elec2',
#        'presencial.masajprof2', 'ENTADULTO.EO2', 'presencial.cardio2',
#        'presencial.extrac2', 'presencial.aacc2', 'FARMA12', 'RRHH28',
#        'EXTRAC20', 'TRAINER23', 'presencial.aacc4', 'LABORA24',
#        'SUEIMP15', 'TERAP26', 'TREFRI26', 'ADUANA5', 'COSME18', 'LOGIS9',
#        'SUEIMP30', 'COMPOFI14', 'ADMREDES12', 'VIANDAS.EO2', 'TERAP11',
#        'AACC29', 'EXTRAC44', 'MASAJISTA30', 'LOGIS4',
#        'presencial.extrac3', 'MANOS10', 'corel.eo1', 'SECREMED19',
#        'ENTFUNCION23', 'AUXCONTA7', 'EVENTOS3', 'RRHH29', 'AACC30',
#        'presencial.aacc3', 'TECEXTRACCB12', 'MECAUTO7', 'PSOLARES1',
#        'TECEXTRACC22', 'edcelu.eo1', 'ENFDOM24', 'EXTRAC45',
#        'resolucionconf.eo1', 'SUEIMP16', 'CELU55', 'FARMA30',
#        'presencial.masajprof3', 'presencial.celu2', 'TECEXTRACC23',
#        'ADMSALUD23', 'RRHH30', 'ENFDOM25', 'CAMARASDESEG1', 'SUEIMP29',
#        'LABORA12', 'TREFRI27', 'EXTRAC22', 'TERAP27', 'COMPOFI15',
#        'FARMA28', 'ENFDOM49', 'TECEXTRACCB14', 'AACC31', 'AUXCONTA9',
#        'MECMOTOS4', 'SUEIMP32', 'SECRE18', 'TRAINER25', 'ADMREDES13',
#        'CELU56', 'LABORA25', 'FARMA31', 'MASAJISTA32', 'EXCELAV14',
#        'MECAUTO8', 'CARDIO50', 'TREFRI28', 'CELU57', 'FARMA14', 'AACC32',
#        'TRAINER24', 'EXTRAC23', 'MASO4M6', 'COSME20', 'presencial.celu3',
#        'ADMSALUD24', 'gastroeddis9', 'ENFDOM50', 'presencial.extrac5',
#        'EXTRAC47', 'TECEXTRACCB8', 'presencial.extrac4', 'ecommerce.eo3',
#        'growthmkt.eo1', 'HEMO9', 'SECREMED20', 'TERAP28', 'AUXCONTA8',
#        'ENFDOM26', 'excelav.eo2', 'RRHH31', 'NUTRIDEPOR.EO2',
#        'AUXCONTA10', 'EXTRAC48', 'presencial.aacc5', 'presencial.elec3',
#        'ADUANA11', 'presencial.elec4', 'RRHH32', 'MASOT14', 'CELU58',
#        'MASAJISTA33', 'presencial.celu4', 'TERAP29',
#        'presencial.masajprof4', 'SUEIMP31', 'PSOLARES2', 'SOFTGEL.EO1',
#        'MECAUTO9', 'COMPOFI16', 'SUEIMP33', 'EXCELAV15', 'RCP24',
#        'HIGIENE7', 'ADMREDES14', 'RCP23', 'MDEPORTIVO9', 'CAMARASDESEG2',
#        'gastroeddis11', 'ADMIN16', 'presencial.enfdomycl2', 'ADMSALUD25',
#        'liderazgo.eo2', 'ENFDOM51', 'REPARAPC2', 'CARDIO51', 'COSME21',
#        'TECCELU4', 'ENFDOM52', 'MECMOTOS3', 'blandas.eo1',
#        'inteligenciaemo.eo1', 'talento.eo1', 'tablasymacros.eo1',
#        'ecommerce.eo1', 'MASO4M10', 'TERAP25', 'MASAJISTA34', 'AACC35',
#        'ELEC27', 'DIGRAF10', 'MASAJISTA35', 'AACC34', 'CELU59',
#        'TREFRI29', 'ADMSALUD26', 'HIGIENE6', 'LABORA26', 'CARDIO53',
#        'ELEC26', 'EXTRAC50', 'EXCELAV16', 'SECRE20', 'RRHH33', 'ADMIN15',
#        'RCP25', 'ENTFUNCION26', 'CELU60', 'TECCELU5', 'COSME22',
#        'celu2.presencial1', 'bartender.eo3', 'MECMOTOS5',
#        'presencial.masajprof5', 'presencial.aacc6', 'PSOLARES3',
#        'SECREMED16', 'presencial.celu5', 'DIGRAF5', 'presencial.extrac6',
#        'SUEIMP34', 'COMPOFI17', 'decotortas38', 'costosgastro4',
#        'TREFRI30', 'COSME23', 'MASO4M8', 'ADMREDES15', 'MECAUTO10',
#        'SECREMED21', 'CAMARASDESEG3', 'EXCELAV17', 'BARTENDER13',
#        'presencial.cardio3', 'TERAP30', 'presencial.elec6',
#        'ENTFUNCION15', 'ENTFUNCION28', 'TRAINER28', 'TRAINER27',
#        'google.s1', 'CAMARASDESEG4', 'CARDIO54', 'FARMA32', 'TREFRI31',
#        'ADMSALUD27', 'COMPOFI18', 'presencial.aacc7', 'MASOT19',
#        'MASO4M12', 'presencial.extrac7', 'presencial.cardio4', 'CELUII8',
#        'RRHH34', 'iaparatrabajo.glex3', 'inteligenciadm.eo1',
#        'presencial.celu6', 'MDEPORTIVO10', 'EXTRAC52', 'FARMA34',
#        'gastroeddis12', 'MASAJISTA36'], dtype=object)

# %%
df['Plan de Estudio'].unique()
# Out:
# array(['AUXILIAR EN SEGURIDAD E HIGIENE EN EL TRABAJO',
#        'INSTALACIÓN Y REPARACIÓN DE AIRES ACONDICIONADOS',
#        'TÉCNICO EN EXTRACCIONISTA',
#        'ASISTENTE DE LABORATORIO DE ANÁLISIS CLÍNICOS', 'COSMETOLOGIA',
#        'MASAJISTA PROFESIONAL', 'COMPUTACION PARA OFICINAS',
#        'PROGRAMACION Y REPARACION DE CELULARES', 'EXTRACCIONISTA',
#        'ADMINISTRACIÓN DE REDES SOCIALES', 'AUXILIAR DE FARMACIA',
#        'ELECTRICISTA INSTALADOR', 'INTRODUCCIÓN AL MUNDO DEL VINO',
#        'SECRETARIADO EJECUTIVO', 'TECNICO EN REFRIGERACION',
#        'EDICIÓN DE FOTOS Y VIDEOS', 'ASISTENTE DE RECURSOS HUMANOS',
#        'TÉCNICO EN EXTRACCIONISTA B',
#        'ASISTENTE DE DESPACHANTE DE ADUANA', 'SECRETARIADO MÉDICO',
#        'ADMINISTRACIÓN HOTELERA', 'BELLEZA DE MANOS Y PIES',
#        'COCINERO DE RESTAURANT virtual', 'PERSONAL TRAINER',
#        'LENGUA DE SEÑAS', 'LIQUIDACIÓN DE SUELDOS E IMPUESTOS',
#        'EXCEL AVANZADO', 'ASISTENTE ADMINISTRATIVO DE PYMES',
#        'PREPARADOR FÍSICO Y DEPORTIVO', 'Pastelería Profesional virtual',
#        'ENFERMERÍA DOMICILIARIA Y CLÍNICA', 'ASESOR TURISTICO',
#        'AUXILIAR EN CARDIOLOGÍA', 'MECANICA DEL AUTOMOTOR',
#        'Decoración de Tortas', 'ASISTENTE TERAPÉUTICO',
#        'ADMINISTRATIVO EN INSTITUCIONES DE SALUD',
#        'ASISTENTE DE LOGÍSTICA Y DISTRIBUCIÓN',
#        'Taller de Pizzas Clasicas', 'NUTRICIÓN DEPORTIVA',
#        'MASAJE DEPORTIVO', 'AUXILIAR CONTABLE', 'ORGANIZACIÓN DE EVENTOS',
#        'RCP PROMO EDDIS ONLINE', 'MASOTERAPIA COMPLEMENTARIO',
#        'TÉCNICAS DE EXTRACCIÓN DE PLASMA EDDIS ONLINE', 'MASOTERAPIA',
#        'INTRODUCCIÓN A LA PROGRAMACIÓN', 'Reparación de celulares',
#        'PROGRAMACIÓN Y REPARACIÓN DE CELULARES II', 'BARTENDER',
#        'TALLER DE VIANDAS SALUDABLES EDDIS ONLINE',
#        'Alfajores artesanales', 'PRIMEROS AUXILIOS + RCP EDDIS ONLINE',
#        'TECNICAS DE MUSCULACIÓN EDDIS ONLINE',
#        'ADMINISTRACIÓN HOTELERA EDDIS ONLINE',
#        'ENTRENAMIENTO FUNCIONAL EDDIS ONLINE', 'ASESORAMIENTO DE IMAGEN',
#        'ASISTENCIAS MÉDICAS + RCP', 'VIANDAS SALUDABLES',
#        'PASTAS GOURMET',
#        'ENTRENAMIENTO FÍSICO EN SOBREPESO Y OBESIDAD EDDIS ONLINE',
#        'TÉCNICAS DE DISEÑO GRÁFICO EN SISTEMAS INFORMÁTICOS',
#        'Taller de Sushi', 'Pastelería para tu emprendimiento',
#        'HUERTA ORGÁNICA EDDIS ONLINE',
#        'ENTRENAMIENTO FÍSICO DEL ADULTO MAYOR EDDIS ONLINE',
#        'Taller Dulces Navideños', 'EXPERTA INTEGRAL EN CEJAS Y PESTAÑAS',
#        'COLORIMETRIA EDDIS ONLINE', 'Técnico/a en uñas',
#        'ENTRENAMIENTO FUNCIONAL',
#        'INTRODUCCIÓN A LA NEUROLINGÜÍSTICA INFANTIL EDDIS ONLINE',
#        'EXTRACCIONISTA PR', 'ASESESORAMIENTO DE IMAGEN EDDIS ONLINE',
#        'AUXILIAR EN ESTIMULACIÓN TEMPRANA',
#        'INTRODUCCIÓN A EXCEL EDDIS ONLINE',
#        'LIDERAZGO Y TOMA DE DECISIONES EDDIS ONLINE',
#        'PASTAS GOURMET EDDIS ONLINE', 'TALLER DE SUSHI EDDIS ONLINE',
#        'TÉCNICO EN CELULARES', 'REPARACIÓN DE PLAYSTATION EDDIS ONLINE',
#        'Peluquería Masculina y Barbería Profesional',
#        'AUXILIAR EN CARDIOLOGIA', 'CUSTOMER EXPERIECE EDDIS ONLINE',
#        'MASAJISTA PROFESIONAL PR',
#        'EXTENSIONISTA PROFESIONAL DE PESTAÑAS', 'CHAT GPT EDDIS ONLINE',
#        'ESPECIAL DE EMPANADAS EDDIS ONLINE',
#        'INTRODUCCIÓN A LA CONTABILIDAD BÁSICA EDDIS ONLINE',
#        'NUTRICION DEPORTIVA EDDIS ONLINE', 'TALLER DE PIZZAS EDDIS ONINE',
#        'DECORACIÓN DE TORTAS EDDIS ONLINE',
#        'MASAS FINAS Y SECAS EDDIS ONLINE',
#        'LIQUIDACIÓN DE SUELDOS EDDIS ONLINE',
#        'EXCEL AVANZADO EDDIS ONLINE', 'POWER BI EDDIS ONLINE',
#        'PROGRAMACIÓN DE VIDEOJUEGOS EDDIS ONLINE',
#        'PASTELERIA PARA TU EMPRENDIMIENTO EDDIS ONLINE',
#        'LIDERAZGO EN MANDOS MEDIOS EDDIS ONLINE',
#        'REPARADOR DE PC Y NOTEBOOK', 'MACARONS EDDIS ONLINE',
#        'INTRODUCCIÓN A WORD EDDIS ONLINE',
#        'AUXILIAR EN SEGURIDAD E HIGIENE EN EL TRABAJO EDDIS ONLINE',
#        'BARTENDER EDDIS ONLINE', 'EDICIÓN DE FOTOS Y VIDEOS EDDIS ONLINE',
#        'Monotributo para Emprendedores Eddis Online',
#        'INSTALADOR Y REPARADOR DE AIRES ACONDICIONADOS',
#        'INTRODUCCIÓN A LA REFLEXOLOGIA',
#        'AMBIENTACION DE EVENTOS EDDIS ONLINE',
#        'ADMINISTRACIÓN DE REDES SOCIALES EDDIS ONLINE',
#        'AUTOMAQUILLAJE EDDIS ONLINE',
#        'PROGRAMACIÓN Y REPARACIÓN AVANZADA DE CELULARES',
#        'INTRODUCCIÓN AUTOCAD EDDIS ONLINE', 'ESTETICA INTEGRAL',
#        'ALFAJORES ARTESANALES EDDIS ONLINE',
#        'GESTION EXISTOSA DE PYMES EDDIS ONLINE',
#        'INTRODUCCIÓN A CANVA EDDIS ONLINE',
#        'INSTRUCTOR DE PILATES EDDIS ONLINE',
#        'Técnica en esmaltado semi y nail art', 'ORATORIA EDDIS ONLINE',
#        'PROGRAMACIÓN Y REPARACIÓN DE CELULARES PR',
#        'FINANZAS PERSONALES EDDIS ONLINE',
#        'HERRAMIENTAS BÁSICAS PARA LA SELECCIÓN DE PERSONAL EDDIS ONLINE',
#        'GESTIÓN DEL TALENTO HUMANO EDDIS ONLINE',
#        'TÉCNICA DE MASAJES EDDIS ONLINE', 'GOOGLE ADS EDDIS ONLINE',
#        'MARKETING DE CONTENIDO PARA REDES SOCIALES EDDIS ONLINE',
#        'DIETA KETO EDDIS ONLINE', 'ENFERMERIA DOMICILIARIA Y CLÍNICA',
#        'Diseño Gráfico con CorelDRAW Eddis Online',
#        'INSTALACIÓN DE PANELES SOLARES FOTOVOLTAICOS',
#        'EDICIÓN DE FOTOS Y VIDEOS CON EL CELULAR EDDIS ONLINE',
#        'RESOLUCIÓN DE CONFLICTOS EN EL ÁMBITO LABORAL',
#        'INSTALACIÓN DE CAMARAS DE SEGURIDAD Y ALARMAS',
#        'MECÁNICA DE MOTOS', 'E COMMERCE EDDIS ONLINE',
#        'Growth Marketing para emprendedores Eddis Online',
#        'AUXILIAR EN HEMOTERAPIA', 'Técnico/a en soft gel',
#        'HABILIDADES BLANDAS EDDIS ONLINE',
#        'INTELIGENCIA EMOCIONAL EN EL TRABAJO',
#        'DESARROLLO DEL TALENTO HUMANO EDDIS ONLINE',
#        'TABLAS DINÁMICAS Y MACROS EN EXCEL INTER. EDDIS ONLINE',
#        'Programación y reparación avanzada de celulares',
#        'COSTOS Y MKT GASTRONOMICO', 'HERRAMIENTAS GOOGLE PARA TU NEGOCIO',
#        'IA para tu trabajo',
#        'Inteligencia Adminsitrativa: Cómo pensar mejor para trabajar mejor'],
#       dtype=object)

# %%
df.Ciudad.unique()
# Out:
# array(['Ezeiza', 'Monte Grande', 'CAÑUELAS', 'GLEW', 'ESTEBAN ECHEVERRIA',
#        'Maximo paz', nan, 'Longchamps', 'Lomas de Zamora', 'El Jaguel',
#        'Luis Guilon', 'Guernica', 'Tristan Suarez', 'Gernica', 'Burzaco',
#        'Lavallol', 'Carlos Spegazzini', 'LA UNION', 'Lanus',
#        'Club de barrio santa rita', 'la matanza', 'JOSE MARMOL',
#        'Virrey del Pino', '2 de Mayo', 'Alejandro Korn', 'Canning',
#        'ROSARIO', 'Máximo Paz', 'gerli', 'Llavallol',
#        'Malvinas Argentinas', 'San Vicente', 'Rafael Calzada',
#        'Partido de la Costa', 'Lavalle', 'Mojón Grande', 'el maiten',
#        'Gonzalez Catan', 'Ciudad Evita', 'Quilmes', 'BUENOS AIRES',
#        'San Ignacio', 'BRANDSEN', 'CaÃ±uelas', 'Ramos Mejia', 'temperley',
#        'san miguel del monte', 'Marcos Paz', 'general las heras',
#        'Uribellarea', 'Villa del Parque', 'CLAYPOLE', '20 de junio',
#        'Canuelas', 'Moron', 'LujÃ¡n de Cuyo', 'Uribelarrea', 'Spegazzini',
#        'vicente casares', 'Lobos', 'Turdera', 'abbott', 'DR LEVENE',
#        'Mercedes', 'Las Heras', 'ALEJANDRO PETION',
#        'Ciudad de Buenos Aires', 'SAN ESTEBAN', 'Tandil',
#        'Capital Federal', 'Rafael Castillo', 'Avellaneda', 'levene',
#        'LAS HERAS', 'LUJAN', 'SARMIENTO', 'Monte Nievas', 'Villa Fiorito',
#        '9 de Abril', 'remedios de escalada', 'Oro verde', 'Santa Rosa',
#        'Adrogue', 'Berazategui', 'Ingeniero Budge', 'banfield',
#        'Victoria', 'Misiones', 'Almirante Brown'], dtype=object)

# %%
df.Genero.unique()
# Out:
# array(['Femenino', 'Masculino'], dtype=object)

# %%
df.Secundario.unique()
# Out:
# array(['SI', 'NO'], dtype=object)

# %%
df.Trabajo.unique()
# Out:
# array(['SI', 'NO'], dtype=object)

# %%
df.Asesor.unique()
# Out:
# array(['YAMILA', 'EDDIS CENTRAL', 'AGOSTINA', 'GABRIELA', 'JACQUELINE',
#        'INGRID', 'SILVINA', 'ASHLEY', 'JONI'], dtype=object)

# %%
df.Edad.unique()
# Out:
# array([39., 36., 37., 45., 40., 23., 28., 24., 26., 44., 43., 25., 55.,
#        33., 22., 48., 30., 53., 34., 42., 54., 38., 21., 29., 47., 50.,
#        19., 46., 31., 35., 20., 57., 56., 41., 27., 32., 58., 18., 49.,
#        52., 16., 51., 17.,  1., 60., 64.,  2., 73., 62., 61., 63., 59.,
#         9., nan, 65., 69., 14., 70., 15., 76., 13.,  0., 67., 68.])

# %%
df.Seña.unique()
# Out:
# array([0, 1])

# %%
df['Fecha Inicio'].unique()
# Out:
# <DatetimeArray>
# ['2023-03-13 00:00:00', '2023-01-09 00:00:00', '2023-02-13 00:00:00',
#  '2023-03-15 00:00:00', '2022-04-11 00:00:00', '2023-04-10 00:00:00',
#  '2023-06-12 00:00:00', '2023-05-15 00:00:00', '2023-08-14 00:00:00',
#  '2023-07-10 00:00:00',
#  ...
#  '2025-11-17 00:00:00', '2025-12-01 00:00:00', '2025-12-11 00:00:00',
#  '2025-12-08 00:00:00', '2025-11-04 00:00:00', '2025-11-07 00:00:00',
#  '2025-11-10 00:00:00', '2025-12-13 00:00:00', '2025-12-19 00:00:00',
#  '2025-11-18 00:00:00']
# Length: 153, dtype: datetime64[ns]

# %%
df.Dia.unique()
# Out:
# array([13,  9, 15, 11, 10, 12, 14, 26, 24, 16, 31,  7,  1,  5,  4, 18,  6,
#         8, 23, 25,  2, 17,  3, 28, 27, 29, 22, 30, 19, 21])

# %%
df.Mes.unique()
# Out:
# array([ 3,  1,  2,  4,  6,  5,  8,  7, 10, 11,  9, 12])

# %%
df.Anio.unique()
# Out:
# array([2023, 2022, 2024, 2025])

# %%
df['Categoria'].unique()
# Out:
# array(['Otros/Sin Categoría', 'Oficios Técnicos y Hogar',
#        'Laboratorio y Extracción', 'Salud y Asistencia Médica',
#        'Estética y Bienestar Personal',
#        'Tecnología y Reparación de Dispositivos', 'Gastronomía y Eventos',
#        'Negocios y Administración'], dtype=object)

# %% [markdown]
# Hipotesis 1: Se plantea que, en al menos uno de los centros, la categoría de curso más popular concentra más del 40\% del total de inscripciones de ese centro, lo cual indicaría una clara especialización local o una demanda significativamente desproporcionada para cierto tipo de formación en esa ubicación particular

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display


plt.figure(figsize=(12, 7))

ax = percentage_table.plot(
    kind='bar',
    stacked=True,
    figsize=(12, 7),
    rot=0,
    ax=plt.gca(),
    cmap='Spectral'
)

plt.title('Proporción Relativa de Planes de Estudio por Centro ', fontsize=16)
plt.xlabel('Centro de Inscripción', fontsize=12)
plt.ylabel('Porcentaje de Inscripciones (%)', fontsize=12)

ax.legend(title='Categoría', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# Tras el análisis de la distribución de las inscripciones, se concluye que la hipótesis planteada sobre una fuerte especialización de los centros no se verifica en los datos. El test cuantitativo que postulaba que la categoría más popular concentraría más del 40\% del total de inscripciones de al menos un centro fue refutado, ya que la máxima concentración observada fue mucho menor. Esto demuestra que no existe una relacion significativa entre la Locación del Centro de inscripción y el Plan de Estudio elegido.

# %% [markdown]
# Hipotesis 2: Se plantea que la edad del inscripto ejerce una influencia significativa en la elección del curso. La mediana de edad de los inscriptos en categorías con un fuerte componente tecnológico y empresarial será notablemente más baja que la mediana de edad de las categorías centradas en servicios asistenciales y oficios tradicionales, demostrando que la edad es un predictor clave de la categoría elegida

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display


plt.figure(figsize=(15, 8))

sns.boxplot(
    x='Categoria',
    y='Edad',
    data=df,
    palette='Spectral'
)

plt.title('Distribución de Edad por Categoría', fontsize=16)
plt.xlabel('Categoría', fontsize=12)
plt.ylabel('Edad', fontsize=12)

plt.xticks(rotation=45, ha='right')

plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2456544998.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# La Hipótesis 2 se confirma, estableciendo una dependencia significativa entre la edad del inscripto y la categoría de curso. La mediana de edad es notablemente más baja en categorías tecnológicas y administrativas, mientras que es más alta en servicios asistenciales y oficios. Por lo tanto, la Edad es un predictor clave para poder anticipar la eleccion

# %% [markdown]
# Hipotesis 3: Se postula que la población desempleada y que no ha terminado el colegio secundario, tienden a elegir categorías de curso que ofrecen una capacitación inicial para insertarse laboralmente. Específicamente, la proporción de inscriptos desempleados y sin los estudios secundarios completos  en categorías como 'Salud y Asistencia Médica' y 'Tecnología y Reparación de Dispositivos' será mayor que la proporción de inscriptos desempleados en la categoría con una menor salida laboral directa como 'Estetica y bienestar'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display


plt.figure(figsize=(12, 7))

sns.barplot(
    x='Desempleados (%)',
    y='Categoria',
    data=h5_data_no,
    palette='Spectral'
)

plt.title('Inscriptos Desempleados por Categoría', fontsize=16)
plt.xlabel('Porcentaje de Desempleados', fontsize=12)
plt.ylabel('Categoría', fontsize=12)


plt.xlim(0, h5_data_no['Desempleados (%)'].max() * 1.2)
plt.grid(axis='x', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1344452005.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display


plt.figure(figsize=(12, 7))

sns.barplot(
    x='Sin Secundario (%)',
    y='Categoria',
    data=h6_data_no,
    palette='Spectral'
)

plt.title('Inscriptos sin Secundario', fontsize=16)
plt.xlabel('Porcentaje sin Secundario', fontsize=12)
plt.ylabel('Categoría', fontsize=12)


plt.xlim(0, h6_data_no['Sin Secundario (%)'].max() * 1.2)
plt.grid(axis='x', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3561636525.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# La hipótesis se confirma ya que los datos evidencian una concentración consistente de la población vulnerable en las categorías de capacitación vocacional directa.Las categorías objetivo, 'Salud y Asistencia Médica' y 'Tecnología y Reparación de Dispositivos', muestran porcentajes de inscriptos desempleados y sin el secundario completo que son visiblemente mayores o están al mismo nivel de concentración que la categoría base 'Estética y Bienestar Personal'
